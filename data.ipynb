# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from preprocess_utils import prepare_data, combine_with_suffix

# %%
data_config = {"x_path": "data/friction_data/features_AgingLaw_v2.csv",
               "y_path": "data/friction_data/targets_AgingLaw_v2.csv",
               'train_samples': 700,
               'log_norm': False,
               'state_norm': True,
               'heal_norm': True}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data = prepare_data(data_config, device)

# %%
x, y = data['train_x_norm'], data['train_y_norm']

noise = torch.randn_like(x) * 0.015
x_noisy = x + noise

N = 150

t = np.linspace(0, 1, N)
t1 = np.linspace(0,1,N//2)
t2 = np.linspace(0,1,38)

plt.plot(t,x_noisy[0,0,:])
plt.plot(t,x_noisy[0,1,:])

plt.plot(t1,x_noisy[0,0,::2])
plt.plot(t1,x_noisy[0,1,::2])

plt.plot(t2,x_noisy[0,0,::4])
plt.plot(t2,x_noisy[0,1,::4])
